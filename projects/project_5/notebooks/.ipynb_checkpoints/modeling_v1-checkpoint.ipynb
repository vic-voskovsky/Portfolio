# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
andrew = pd.read_csv('../new_datasets/andrew.csv')
charlie = pd.read_csv('../new_datasets/charlie.csv')
frances = pd.read_csv('../new_datasets/frances.csv')
harvey = pd.read_csv('../new_datasets/harvey.csv')
ike = pd.read_csv('../new_datasets/ike.csv')
irene = pd.read_csv('../new_datasets/irene.csv')
irma = pd.read_csv('../new_datasets/irma.csv')
ivan = pd.read_csv('../new_datasets/ivan.csv')
katrina = pd.read_csv('../new_datasets/katrina.csv')
maria = pd.read_csv('../new_datasets/maria.csv')
matthew = pd.read_csv('../new_datasets/matthew.csv')
michael = pd.read_csv('../new_datasets/michael.csv')
rita = pd.read_csv('../new_datasets/rita.csv')
sandy = pd.read_csv('../new_datasets/sandy.csv')
wilma = pd.read_csv('../new_datasets/wilma.csv')

df = pd.concat([andrew, charlie, frances, harvey, ike, irene, irma, ivan, katrina, maria, matthew, michael, rita, sandy, wilma])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-62a8051b9621> in <module>
# ----> 1 andrew = pd.read_csv('../new_datasets/andrew.csv')
#       2 charlie = pd.read_csv('../new_datasets/charlie.csv')
#       3 frances = pd.read_csv('../new_datasets/frances.csv')
#       4 harvey = pd.read_csv('../new_datasets/harvey.csv')
#       5 ike = pd.read_csv('../new_datasets/ike.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../new_datasets/andrew.csv does not exist: '../new_datasets/andrew.csv'

# %%
cost_df = pd.read_csv('../new_datasets/cost.csv')

# %%
industry_df = pd.read_csv('../Proect_5/datasets/industry_data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-96-8ef6a74d6705> in <module>
# ----> 1 industry_df = pd.read_csv('../Proect_5/datasets/industry_data')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../Proect_5/datasets/industry_data does not exist: '../Proect_5/datasets/industry_data'

# %%
cost_df
# Out:
#     rank      name      states  year  category  damage  adjusted_damage
# 0      1   Katrina  FL, LA, MS  2005         3   125.0            160.0
# 1      2    Harvey      TX, LA  2017         4   125.0            125.0
# 2      3     Maria          PR  2017         5    90.0             90.0
# 3      4     Sandy  NY, NJ, MA  2012         1    65.0             70.2
# 4      5      Irma          FL  2017         5    50.0             50.0
# 5      6    Andrew      FL, LA  1992         5    27.0             47.8
# 6      7       Ike      TX, LA  2008         2    30.0             34.8
# 7      8      Ivan      AL, FL  2004         3    20.5             27.1
# 8      9     Wilma          FL  2005         3    19.0             24.3
# 9     10      Rita      LA, TX  2005         3    18.5             23.7
# 10    11  Florence          NC  2018         1    24.0             24.0
# 11    12   Charlie          FL  2004         4    16.0             21.1
# 12    13     Irene          NC  2011         1    13.5             14.9
# 13    14   Matthew       SE US  2016         1    10.0             10.3
# 14    15   Frances          FL  2004         2     9.8             12.9
# 15    16   Allison          TX  2001         1     8.5             11.8
# 16    17    Jeanne          FL  2004         3     7.5              9.9
# 17    18      Hugo          SC  1989         4     7.0             14.1
# 18    19     Floyd      NY, MA  1999         2     6.5              9.6
# 19    20    Gustav          LA  2008         2     6.0              6.9
# 20    21   Michael      FL, GA  2018         5    25.1             25.1

# %%
new_df = pd.merge(df, cost_df, left_on=['geoid'], right_on=['name'], how='inner')

# %%
new_df
# Out:
#        geoid  area_fips  \
# 0     Andrew      12011
# 1     Andrew      12099
# 2     Andrew      12087
# 3    Charlie      12021
# 4    Charlie      12015
# ..       ...        ...
# 118    Wilma      12099
# 119    Wilma      12071
# 120    Wilma      12087
# 121    Wilma      12043
# 122    Wilma      12051
#
#      qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                 96.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 98.0
# 4                                                 21.0
# ..                                                 ...
# 118                                              366.0
# 119                                              116.0
# 120                                               25.0
# 121                                               18.0
# 122                                               97.0
#
#      avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                299.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                377.0
# 4                                                398.0
# ..                                                 ...
# 118                                              510.0
# 119                                              471.0
# 120                                              514.0
# 121                                                0.0
# 122                                                0.0
#
#      month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                930.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                               3947.0
# 4                                                386.0
# ..                                                 ...
# 118                                             6403.0
# 119                                             1707.0
# 120                                               90.0
# 121                                                0.0
# 122                                                0.0
#
#      lq_avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                 1.12
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 1.01
# 4                                                 1.22
# ..                                                 ...
# 118                                               1.19
# 119                                               1.22
# 120                                               1.46
# 121                                               0.00
# 122                                               0.00
#
#      lq_qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                 0.16
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 0.80
# 4                                                 0.50
# ..                                                 ...
# 118                                               0.70
# 119                                               0.60
# 120                                               0.53
# 121                                              11.71
# 122                                              11.76
#
#      lq_month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# 0                                                 0.17
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 3.52
# 4                                                 1.04
# ..                                                 ...
# 118                                               1.22
# 119                                               0.85
# 120                                               0.26
# 121                                               0.00
# 122                                               0.00
#
#      qtrly_estabs_1024_professional_and_business_services  \
# 0                                               7227.0
# 1                                               5314.0
# 2                                                354.0
# 3                                               2183.0
# 4                                                589.0
# ..                                                 ...
# 118                                            10980.0
# 119                                             3134.0
# 120                                              661.0
# 121                                               14.0
# 122                                               77.0
#
#      avg_wkly_wage_1024_professional_and_business_services  ...  \
# 0                                                466.0      ...
# 1                                                548.0      ...
# 2                                                470.0      ...
# 3                                                676.0      ...
# 4                                                597.0      ...
# ..                                                 ...      ...
# 118                                              823.0      ...
# 119                                              717.0      ...
# 120                                              774.0      ...
# 121                                              457.0      ...
# 122                                              455.0      ...
#
#      lq_avg_wkly_wage_48_49_transportation_and_warehousing.3  \
# 0                                                 0.92
# 1                                                 0.93
# 2                                                 0.89
# 3                                                 1.01
# 4                                                 0.98
# ..                                                 ...
# 118                                               1.46
# 119                                               0.97
# 120                                               0.00
# 121                                               0.00
# 122                                               1.01
#
#      lq_qtrly_estabs_48_49_transportation_and_warehousing.3  \
# 0                                                 0.85
# 1                                                 1.16
# 2                                                 0.60
# 3                                                 0.74
# 4                                                 1.00
# ..                                                 ...
# 118                                               0.82
# 119                                               0.93
# 120                                               1.24
# 121                                               1.03
# 122                                               1.38
#
#      lq_month3_emplvl_48_49_transportation_and_warehousing.3  rank     name  \
# 0                                                 1.21           6   Andrew
# 1                                                 0.73           6   Andrew
# 2                                                 0.42           6   Andrew
# 3                                                 0.36          12  Charlie
# 4                                                 0.96          12  Charlie
# ..                                                 ...         ...      ...
# 118                                               0.51           9    Wilma
# 119                                               0.95           9    Wilma
# 120                                               0.00           9    Wilma
# 121                                               0.00           9    Wilma
# 122                                               0.69           9    Wilma
#
#      states  year  category  damage  adjusted_damage
# 0    FL, LA  1992         5    27.0             47.8
# 1    FL, LA  1992         5    27.0             47.8
# 2    FL, LA  1992         5    27.0             47.8
# 3        FL  2004         4    16.0             21.1
# 4        FL  2004         4    16.0             21.1
# ..      ...   ...       ...     ...              ...
# 118      FL  2005         3    19.0             24.3
# 119      FL  2005         3    19.0             24.3
# 120      FL  2005         3    19.0             24.3
# 121      FL  2005         3    19.0             24.3
# 122      FL  2005         3    19.0             24.3
#
# [123 rows x 783 columns]

# %%
new_df['damage_by_county'] = 0
for i in new_df['geoid'].unique():
    count = new_df[new_df['geoid'] == i].shape[0]
    print(count)
    new_df.loc[new_df['geoid'] == i,'damage_by_county'] = new_df.loc[new_df['geoid'] == i,'adjusted_damage'] * .8/count
# Out:
# 3
# 6
# 11
# 9
# 4
# 16
# 13
# 11
# 6
# 5
# 7
# 7
# 12
# 6
# 7

# %%
df_no_andrew = new_df.drop(axis='index',index=[0,1,2])

# %%
df_no_andrew
# Out:
#        geoid  area_fips  \
# 3    Charlie      12021
# 4    Charlie      12015
# 5    Charlie      12095
# 6    Charlie      12027
# 7    Charlie      12087
# ..       ...        ...
# 118    Wilma      12099
# 119    Wilma      12071
# 120    Wilma      12087
# 121    Wilma      12043
# 122    Wilma      12051
#
#      qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 3                                                 98.0
# 4                                                 21.0
# 5                                                231.0
# 6                                                118.0
# 7                                                 26.0
# ..                                                 ...
# 118                                              366.0
# 119                                              116.0
# 120                                               25.0
# 121                                               18.0
# 122                                               97.0
#
#      avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 3                                                377.0
# 4                                                398.0
# 5                                                427.0
# 6                                                  0.0
# 7                                                  0.0
# ..                                                 ...
# 118                                              510.0
# 119                                              471.0
# 120                                              514.0
# 121                                                0.0
# 122                                                0.0
#
#      month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# 3                                               3947.0
# 4                                                386.0
# 5                                               4534.0
# 6                                                  0.0
# 7                                                  0.0
# ..                                                 ...
# 118                                             6403.0
# 119                                             1707.0
# 120                                               90.0
# 121                                                0.0
# 122                                                0.0
#
#      lq_avg_wkly_wage_11_agriculture_forestry_fishing_and_hunting  \
# 3                                                 1.01
# 4                                                 1.22
# 5                                                 1.11
# 6                                                 0.00
# 7                                                 0.00
# ..                                                 ...
# 118                                               1.19
# 119                                               1.22
# 120                                               1.46
# 121                                               0.00
# 122                                               0.00
#
#      lq_qtrly_estabs_11_agriculture_forestry_fishing_and_hunting  \
# 3                                                 0.80
# 4                                                 0.50
# 5                                                 0.65
# 6                                                17.03
# 7                                                 0.55
# ..                                                 ...
# 118                                               0.70
# 119                                               0.60
# 120                                               0.53
# 121                                              11.71
# 122                                              11.76
#
#      lq_month3_emplvl_11_agriculture_forestry_fishing_and_hunting  \
# 3                                                 3.52
# 4                                                 1.04
# 5                                                 0.74
# 6                                                 0.00
# 7                                                 0.00
# ..                                                 ...
# 118                                               1.22
# 119                                               0.85
# 120                                               0.26
# 121                                               0.00
# 122                                               0.00
#
#      qtrly_estabs_1024_professional_and_business_services  \
# 3                                               2183.0
# 4                                                589.0
# 5                                               6799.0
# 6                                                 46.0
# 7                                                643.0
# ..                                                 ...
# 118                                            10980.0
# 119                                             3134.0
# 120                                              661.0
# 121                                               14.0
# 122                                               77.0
#
#      avg_wkly_wage_1024_professional_and_business_services  ...  \
# 3                                                676.0      ...
# 4                                                597.0      ...
# 5                                                758.0      ...
# 6                                                630.0      ...
# 7                                                735.0      ...
# ..                                                 ...      ...
# 118                                              823.0      ...
# 119                                              717.0      ...
# 120                                              774.0      ...
# 121                                              457.0      ...
# 122                                              455.0      ...
#
#      lq_qtrly_estabs_48_49_transportation_and_warehousing.3  \
# 3                                                 0.74
# 4                                                 1.00
# 5                                                 1.37
# 6                                                 1.01
# 7                                                 1.11
# ..                                                 ...
# 118                                               0.82
# 119                                               0.93
# 120                                               1.24
# 121                                               1.03
# 122                                               1.38
#
#      lq_month3_emplvl_48_49_transportation_and_warehousing.3  rank     name  \
# 3                                                 0.36          12  Charlie
# 4                                                 0.96          12  Charlie
# 5                                                 0.70          12  Charlie
# 6                                                 0.00          12  Charlie
# 7                                                 0.00          12  Charlie
# ..                                                 ...         ...      ...
# 118                                               0.51           9    Wilma
# 119                                               0.95           9    Wilma
# 120                                               0.00           9    Wilma
# 121                                               0.00           9    Wilma
# 122                                               0.69           9    Wilma
#
#      states  year  category  damage  adjusted_damage  damage_by_county
# 3        FL  2004         4    16.0             21.1          2.813333
# 4        FL  2004         4    16.0             21.1          2.813333
# 5        FL  2004         4    16.0             21.1          2.813333
# 6        FL  2004         4    16.0             21.1          2.813333
# 7        FL  2004         4    16.0             21.1          2.813333
# ..      ...   ...       ...     ...              ...               ...
# 118      FL  2005         3    19.0             24.3          2.777143
# 119      FL  2005         3    19.0             24.3          2.777143
# 120      FL  2005         3    19.0             24.3          2.777143
# 121      FL  2005         3    19.0             24.3          2.777143
# 122      FL  2005         3    19.0             24.3          2.777143
#
# [120 rows x 784 columns]

# %%
wage = pd.read_csv('../new_datasets/wage.csv')

# %%
y = new_df['Damage(Adjusted for Inflation)']

# %%
X = new_df.drop(columns=['geoid', 'area_fips', 'Rank', 'Name', 'States', 'Year', 'Category', 'Damage (B$)', 'Damage(Adjusted for Inflation)'])
